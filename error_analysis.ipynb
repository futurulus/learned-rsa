# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import json
import numpy as np
from collections import defaultdict
from glob import glob
from IPython.core.display import HTML
from metrics import accuracy, mean_multiset_dice
from tuna import TunaCorpus
from utils import confidence_interval

# %%
def load_predictions(run_dir):
    result = []
    for filename in glob(os.path.join(run_dir, 'predictions.*.jsons')):
        split = []
        with open(filename, 'r') as infile:
            for line in infile:
                split.append(json.loads(line))
        result.append(split)
    return result

# %%
def evaluate(preds, metrics):
    evals = [np.array([m([e['prediction'] for e in split],
                         [e['gold'] for e in split])
                       for split in preds])
             for m in metrics]
    
    return ', '.join('%.3f (%.3f--%.3f)' %
                     ((e.mean(),) + tuple(confidence_interval(e)))
                     for e in evals)

def evaluate_mean(preds, metrics):
    evals = [m([e['prediction'] for split in preds for e in split],
               [e['gold'] for split in preds for e in split])
             for m in metrics]
    
    return ', '.join('%d / %d (%6.3f)' % e
                     for e in evals)

def is_loc(gold):
    if '[' in gold:
        gold = eval(gold)
    return any('dimension' in a for a in gold)

# %%
PLUSLOC_TRIALS = set()
for trial in TunaCorpus(filenames=glob('../TUNA/corpus/*/*/*.xml')).iter_trials():
    if trial.condition == '+LOC':
        PLUSLOC_TRIALS.add(trial.id)
    else:
        assert trial.condition == '-LOC'

def filter_loc(preds, loc=[True, False]):
    return [[e for e in split
             if (e['id'] in PLUSLOC_TRIALS) in loc]
            for split in preds]

# %%
furniture = load_predictions('runs/306')
people = load_predictions('runs/307')
combined = [f + p for f, p in zip(furniture, people)]

furniture_loc = filter_loc(furniture, [True])
furniture_no_loc = filter_loc(furniture, [False])
people_loc = filter_loc(people, [True])
people_no_loc = filter_loc(people, [False])
combined_loc = filter_loc(combined, [True])
combined_no_loc = filter_loc(combined, [False])

for preds in [furniture, people,
              furniture_loc, people_loc,
              furniture_no_loc, people_no_loc,
              combined,
              combined_loc, combined_no_loc]:
    if not any(len(s) for s in preds):
        print 'no examples'
    else:
        print evaluate(preds, [accuracy, mean_multiset_dice])
# Out:
# 0.281 (0.217--0.324), 0.812 (0.793--0.825)
# 0.178 (0.094--0.211), 0.730 (0.716--0.746)
# 0.286 (0.227--0.337), 0.811 (0.795--0.832)
# 0.106 (0.055--0.175), 0.716 (0.680--0.736)
# 0.280 (0.201--0.342), 0.814 (0.788--0.825)
# 0.237 (0.109--0.294), 0.741 (0.704--0.759)
# 0.233 (0.197--0.267), 0.774 (0.758--0.786)
# 0.206 (0.160--0.248), 0.768 (0.743--0.781)
# 0.259 (0.221--0.302), 0.780 (0.769--0.791)

# %%
from error_analysis import predicted_proper_subset_stats, what_get_left_out_stats

def stats(predictions, golds, stats_func=predicted_proper_subset_stats):
    log = [{'agent': {'prediction': eval(pred), 'actual': eval(gold)}}
           for pred, gold in zip(predictions, golds)]
    return stats_func(log, agentname='agent')

def proper_subset_frac(predictions, golds):
    return stats(predictions, golds)

predicted_proper_superset_stats = lambda log, agentname: predicted_proper_subset_stats(log, agentname, overproduce=True)
def proper_superset_frac(predictions, golds):
    return stats(predictions, golds, predicted_proper_superset_stats)

def left_out(predictions, golds):
    stats(predictions, golds, what_get_left_out_stats)
    return (0, 0, 0.0)

# %%
runs = [['275', '276'],
        ['306', '307'],
        ['251', '252'],
        ['308', '309']]

for furn_run, people_run in runs:
    furniture = load_predictions('runs/%s' % furn_run)
    people = load_predictions('runs/%s' % people_run)
    combined = [f + p for f, p in zip(furniture, people)]

    scores = []
    for preds in [furniture, people, combined]:
        if not any(len(s) for s in preds):
            scores.append('no examples')
        else:
            scores.append(evaluate_mean(preds, [proper_superset_frac]))  # [accuracy, mean_multiset_dice]))
    print ' | '.join(('%22s' % e) for e in scores)
# Out:
#       0 / 353 ( 0.000) |       0 / 326 ( 0.000) |       0 / 679 ( 0.000)
#       0 / 302 ( 0.000) |       0 / 296 ( 0.000) |       0 / 598 ( 0.000)
#       0 / 323 ( 0.000) |       0 / 317 ( 0.000) |       0 / 640 ( 0.000)
#       0 / 304 ( 0.000) |       0 / 279 ( 0.000) |       0 / 583 ( 0.000)

# %%
for furn_run, people_run in runs:
    furniture = load_predictions('runs/%s' % furn_run)
    people = load_predictions('runs/%s' % people_run)

    for name, run, preds in [('furniture', furn_run, furniture),
                        ('people', people_run, people)]:
        print '------'
        print '%s (%s)' % (name, run)
        if not any(len(s) for s in preds):
            print 'no examples'
        else:
            evaluate_mean(preds, [left_out])
# Out:
# ------
# furniture (275)
# y-dimension:3 41
# size:large 38
# y-dimension:1 37
# size:small 23
# orientation:back 21
# ------
# people (276)
# hairColour:light 63
# hasBeard:1 62
# hasGlasses:1 48
# hasHair:1 33
# y-dimension:3 24
# ------
# furniture (306)
# y-dimension:1 39
# y-dimension:3 32
# y-dimension:2 28
# size:large 24
# orientation:left 21
# ------
# people (307)
# hasBeard:1 71
# hairColour:light 40
# hasHair:1 30
# y-dimension:1 26
# y-dimension:3 25
# ------
# furniture (251)
# y-dimension:3 48
# size:large 40
# y-dimension:1 40
# y-dimension:2 31
# orientation:right 28
# ------
# people (252)
# type:person 103
# hairColour:light 26
# y-dimension:2 24
# hairColour:dark 22
# y-dimension:3 20
# ------
# furniture (308)
# y-dimension:3 50
# y-dimension:1 46
# size:large 35
# orientation:front 33
# orientation:right 31
# ------
# people (309)
# y-dimension:1 30
# hasHair:1 28
# hairColour:dark 28
# hairColour:light 24
# y-dimension:3 23

# %%
p = load_predictions('runs/275')
p[0][0]

def mapify(preds):
    return {ex['id']: ex for split in preds for ex in split}

mp = mapify(p)
mp['s40t6']
# Out:
# {u'gold': u"['colour:green', 'orientation:front', 'size:small', 'type:desk']",
#  u'id': u's40t6',
#  u'input': u"['colour:green', 'orientation:front', 'size:small', 'type:desk', 'x-dimension:1', 'y-dimension:1']",
#  u'prediction': u"['colour:green', 'type:desk', 'y-dimension:1']"}

# %%
all_maps = []

furn_p = []
people_p = []
combined_p = []

example_ids = sorted(mapify(load_predictions('runs/%s' % runs[0][0])).keys())

from scipy.stats import wilcoxon

for furn_run, people_run in runs:
    furniture = mapify(load_predictions('runs/%s' % furn_run))
    people = mapify(load_predictions('runs/%s' % people_run))
    combined = dict(furniture)
    combined.update(people)
    
    all_maps.append([furniture, people, combined])

def safe_wilcoxon(a, b):
    if all(a == b): return 1.0
    else: return wilcoxon(a, b)[1]

for metric in [accuracy, mean_multiset_dice]:
    print
    print metric.__name__
    
    for subset in range(0, 3):
        print ['furniture', 'people', 'all'][subset]
        
        subset_runs = [(r[0], r[1], r)[subset] for r in runs]
        subset_evals = [np.array([metric([e['prediction']], [e['gold']])
                                  for e in m[subset].values()])
                        for m in all_maps]
        print '                    ' + ' '.join('%10s (%5.3f)' % (run, subset_eval.mean())
                                    for run, subset_eval in zip(subset_runs, subset_evals))
        
        for run_1, subset_eval_1 in zip(subset_runs, subset_evals):
            header = '%10s (%5.3f)' % (run_1, subset_eval_1.mean())
            print header + ' '.join('%18.3g' % safe_wilcoxon(subset_eval_1, subset_eval_2)
                                    for _, subset_eval_2 in zip(subset_runs, subset_evals))
# Out:
# accuracy
# furniture
#                            275 (0.160)        306 (0.281)        251 (0.231)        308 (0.276)
#        275 (0.160)                 1           4.56e-08           0.000796            2.8e-07
#        306 (0.281)          4.56e-08                  1             0.0196              0.808
#        251 (0.231)          0.000796             0.0196                  1            0.00179
#        308 (0.276)           2.8e-07              0.808            0.00179                  1
# people
#                            276 (0.094)        307 (0.178)        252 (0.119)        309 (0.225)
#        276 (0.094)                 1            6.1e-05              0.189           5.55e-09
#        307 (0.178)           6.1e-05                  1            0.00717             0.0378
#        252 (0.119)             0.189            0.00717                  1           2.11e-08
#        309 (0.225)          5.55e-09             0.0378           2.11e-08                  1
# all
#                     ['275', '276'] (0.129) ['306', '307'] (0.233) ['251', '252'] (0.179) ['308', '309'] (0.253)
# ['275', '276'] (0.129)                 1           1.26e-11           0.000539           1.52e-14
# ['306', '307'] (0.233)          1.26e-11                  1           0.000424              0.197
# ['251', '252'] (0.179)          0.000539           0.000424                  1           3.94e-10
# ['308', '309'] (0.253)          1.52e-14              0.197           3.94e-10                  1
#
# mean_multiset_dice
# furniture
#                            275 (0.779)        306 (0.812)        251 (0.789)        308 (0.788)
#        275 (0.779)                 1           1.34e-05              0.331              0.485
#        306 (0.812)          1.34e-05                  1           0.000192           5.26e-05
#        251 (0.789)             0.331           0.000192                  1              0.934
#        308 (0.788)             0.485           5.26e-05              0.934                  1
# people
#                            276 (0.697)        307 (0.730)        252 (0.740)        309 (0.764)
#        276 (0.697)                 1            0.00101           5.98e-06           5.55e-11
#        307 (0.730)           0.00101                  1              0.217           0.000318
#        252 (0.740)          5.98e-06              0.217                  1           0.000377
#        309 (0.764)          5.55e-11           0.000318           0.000377                  1
# all
#                     ['275', '276'] (0.741) ['306', '307'] (0.774) ['251', '252'] (0.766) ['308', '309'] (0.777)
# ['275', '276'] (0.741)                 1           6.45e-08             0.0001           1.99e-07
# ['306', '307'] (0.774)          6.45e-08                  1              0.104              0.877
# ['251', '252'] (0.766)            0.0001              0.104                  1            0.00469
# ['308', '309'] (0.777)          1.99e-07              0.877            0.00469                  1

# %%
confidence_interval([2.0, 3.6, 2.0, 3.0])
# Out:
# array([ 2. ,  3.2])

# %%
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %%
def acc(x, y):
    if y == 0:
        return '0.000'
    else:
        return '%0.3f' % (x * 1.0 / y)

def collate_example_stats(*experiments):
    eval_count = []
    outputs = []
    correct_count = []
    ex_by_id = {}
    
    for predictions in experiments:
        eval_count.append(defaultdict(int))
        correct_count.append(defaultdict(int))
        outputs.append(defaultdict(list))

        for split in predictions:
            for example in split:
                ex_by_id[example['id']] = (example['input'], example['gold'])
                outputs[-1][example['id']].append(example['prediction'])
                eval_count[-1][example['id']] += 1
                if example['prediction'] == example['gold']:
                    correct_count[-1][example['id']] += 1
    
    table = []
    for i in ex_by_id:
        table.append([i])
        for e in range(len(eval_count)):
            table[-1] += [correct_count[e][i], eval_count[e][i],
                          acc(correct_count[e][i], eval_count[e][i]),
                          '<br/>'.join(str(o) for o in outputs[e][i])]
        table[-1] += ex_by_id[i]

    if len(eval_count) == 1:
        sortkey = lambda row: float(row[3])
    else:
        sortkey = lambda row: float(row[4 * len(eval_count) - 1]) - float(row[3])
    return sorted(table, key=sortkey), \
           ['id'] + ['correct', 'total', 'acc', 'predictions'] * len(eval_count) + \
           ['utt', 'gold']

# %%
good = load_predictions('runs/309')
bad = load_predictions('runs/307')

# %%
print len(good), len(bad)
print len(good[0]), len(bad[0])
# Out:
# 5 5
# 72 72

# %%
table, rownames = collate_example_stats(good, bad)
len(table)
# Out:
# 360

# %%
def display_html(table, row_names):
    html_table = ListTable()
    html_table.append(row_names)
    for row in table:
        html_table.append(row)
    return html_table

display_html(table, rownames)
# Out:
# [['id',
#   'correct',
#   'total',
#   'acc',
#   'predictions',
#   'correct',
#   'total',
#   'acc',
#   'predictions',
#   'utt',
#   'gold'],
#  [u's312t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['age:old', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's312t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's28t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's97t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's323t21',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's323t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's177t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's149t23',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's53t23',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's192t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's20t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's114t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's393t23',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person', 'y-dimension:3']"],
#  [u's49t23',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's108t21',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's131t26',
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's331t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's331t23',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's313t21',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's18t26',
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's97t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['age:old', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's97t23',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's401t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's4t25',
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:unknown', 'y-dimension:unknown']",
#   0,
#   1,
#   '0.000',
#   "['x-dimension:unknown', 'y-dimension:unknown']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:unknown', 'y-dimension:unknown']",
#   u"['type:person', 'x-dimension:unknown', 'y-dimension:unknown']"],
#  [u's4t22',
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:unknown', 'y-dimension:unknown']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:unknown']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:unknown', 'y-dimension:unknown']",
#   u"['type:person', 'x-dimension:unknown', 'y-dimension:unknown']"],
#  [u's37t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's326t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['age:old', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's191t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['age:old', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's402t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:2']"],
#  [u's120t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:2']"],
#  [u's400t25',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's400t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:1']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:1']"],
#  [u's81t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's81t21',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's73t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's102t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's59t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's307t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'y-dimension:3']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's197t26',
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:1']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:4', 'y-dimension:1']"],
#  [u's320t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's320t25',
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:1']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:1', 'y-dimension:1']"],
#  [u's320t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's78t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person', 'y-dimension:3']"],
#  [u's78t23',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'y-dimension:3']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's78t21',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's78t26',
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasGlasses:1', 'hasSuit:1', 'type:person', 'y-dimension:2']"],
#  [u's78t24',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['hairColour:light', 'hasGlasses:1', 'hasHair:1', 'type:person', 'x-dimension:3', 'y-dimension:2']"],
#  [u's78t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'hasHair:0', 'type:person', 'y-dimension:3']"],
#  [u's310t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['y-dimension:1']"],
#  [u's310t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's310t25',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['hasBeard:1', 'type:person', 'y-dimension:1']"],
#  [u's310t22',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's310t23',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:3', 'y-dimension:1']"],
#  [u's310t21',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's48t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's48t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person', 'x-dimension:3', 'y-dimension:1']"],
#  [u's48t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:1']"],
#  [u's48t23',
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person', 'y-dimension:1']"],
#  [u's48t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['type:person', 'x-dimension:4', 'y-dimension:2']"],
#  [u's312t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'y-dimension:1']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:4', 'y-dimension:1']"],
#  [u's197t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasBeard:1', 'type:person', 'y-dimension:3']"],
#  [u's197t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['type:person', 'x-dimension:2', 'y-dimension:3']"],
#  [u's197t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's312t23',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:1']"],
#  [u's28t23',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person', 'y-dimension:2']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['type:person', 'x-dimension:3', 'y-dimension:2']"],
#  [u's28t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['type:person', 'x-dimension:3', 'y-dimension:3']"],
#  [u's28t26',
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'orientation:front', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['type:person', 'x-dimension:2', 'y-dimension:3']"],
#  [u's28t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:3', 'y-dimension:1']"],
#  [u's28t24',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['type:person', 'x-dimension:3', 'y-dimension:2']"],
#  [u's323t25',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:2']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's323t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['age:young', 'hasGlasses:1', 'type:person']"],
#  [u's97t26',
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasGlasses:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'type:person']"],
#  [u's97t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's97t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's177t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's177t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasHair:1', 'type:person']"],
#  [u's177t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's149t26',
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's149t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's149t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'hasHair:0', 'type:person']"],
#  [u's149t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'hasShirt:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's149t21',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's50t21',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's50t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's50t23',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's50t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's50t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's50t26',
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's53t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['hairColour:light', 'hasBeard:1', 'orientation:left', 'type:person']"],
#  [u's53t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's53t26',
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's53t21',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's53t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person', 'y-dimension:3']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person']"],
#  [u's81t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's181t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['type:person', 'x-dimension:5', 'y-dimension:3']"],
#  [u's181t23',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'y-dimension:3']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's181t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:1', 'y-dimension:1']"],
#  [u's181t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:1']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['hairColour:dark', 'hasHair:1', 'type:person']"],
#  [u's181t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's181t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:1', 'y-dimension:1']"],
#  [u's102t26',
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:4', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'y-dimension:1']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's60t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's60t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:1']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['hairColour:light', 'hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's60t24',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['hairColour:light', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's60t23',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'y-dimension:3']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:light', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's60t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['hairColour:dark', 'hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person']"],
#  [u's60t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'hasHair:1', 'type:person']"],
#  [u's195t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1']"],
#  [u's195t24',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasGlasses:1']"],
#  [u's329t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['x-dimension:3', 'y-dimension:3']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's195t22',
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person', 'x-dimension:3', 'y-dimension:2']"],
#  [u's192t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['hairColour:dark', 'hasBeard:1', 'hasHair:1', 'orientation:front', 'type:person']"],
#  [u's192t23',
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's192t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'orientation:front', 'type:person']"],
#  [u's192t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['hasGlasses:1', 'orientation:front', 'type:person']"],
#  [u's192t24',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['age:old', 'hasGlasses:1', 'type:person']"],
#  [u's62t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
# ...
#  [u's59t23',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's59t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's307t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:2']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasGlasses:1', 'hasSuit:1', 'hasTie:1', 'type:person']"],
#  [u's307t25',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['x-dimension:3', 'y-dimension:3']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's307t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'x-dimension:2']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hasBeard:1', 'hasTie:0', 'type:person']"],
#  [u's307t21',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person', 'x-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's169t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's169t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['hairColour:dark', 'hairColour:dark', 'hasBeard:1', 'hasHair:1', 'type:person']"],
#  [u's169t23',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's169t24',
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's169t25',
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's169t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:3']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasSuit:1', 'type:person', 'y-dimension:3']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's320t21',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'x-dimension:1']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's320t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   0,
#   1,
#   '0.000',
#   "['age:young', 'hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person', 'y-dimension:2']"],
#  [u's48t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:3']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's312t25',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hairColour:light', 'hasBeard:1', 'type:person']"],
#  [u's177t23',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's177t22',
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's62t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:5', 'y-dimension:1']"],
#  [u's20t23',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's20t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's101t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'y-dimension:3']",
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:3']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's40t22',
#   0,
#   1,
#   '0.000',
#   "['hairColour:dark', 'hasBeard:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasBeard:1', 'type:person']"],
#  [u's114t26',
#   0,
#   1,
#   '0.000',
#   "['type:person', 'x-dimension:3', 'y-dimension:3']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:3']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's312t21',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:5', 'y-dimension:1']"],
#  [u's57t24',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['age:old', 'hairColour:light', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['type:person', 'x-dimension:1', 'y-dimension:3']"],
#  [u's331t22',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:1', 'hasGlasses:0', 'hasHair:1', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['type:person', 'x-dimension:1', 'y-dimension:3']"],
#  [u's132t21',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:3']",
#   u"['type:person', 'x-dimension:1', 'y-dimension:3']"],
#  [u's132t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['age:young ', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:2']",
#   u"['type:person', 'x-dimension:3', 'y-dimension:2']"],
#  [u's379t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'hasHair:1', 'type:person', 'y-dimension:1']",
#   1,
#   1,
#   '1.000',
#   "['x-dimension:3', 'y-dimension:1']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['x-dimension:3', 'y-dimension:1']"],
#  [u's326t21',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person', 'x-dimension:4']",
#   1,
#   1,
#   '1.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:4', 'y-dimension:2']",
#   u"['hasBeard:1', 'hasGlasses:1', 'type:person']"],
#  [u's120t25',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'type:person', 'y-dimension:1']",
#   1,
#   1,
#   '1.000',
#   "['type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:0', 'hasHair:0', 'hasShirt:1', 'hasSuit:0', 'hasTie:0', 'orientation:left', 'type:person', 'x-dimension:5', 'y-dimension:1']",
#   u"['type:person', 'x-dimension:5', 'y-dimension:1']"],
#  [u's400t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person', 'x-dimension:2', 'y-dimension:1']"],
#  [u's401t26',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']",
#   u"['age:young', 'hairColour:dark', 'hasBeard:0', 'hasGlasses:1', 'hasHair:1', 'hasShirt:1', 'hasSuit:1', 'hasTie:1', 'orientation:front', 'type:person', 'x-dimension:1', 'y-dimension:2']",
#   u"['hairColour:dark', 'hasGlasses:1', 'hasHair:1', 'type:person']"],
#  [u's389t23',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['x-dimension:2', 'y-dimension:1']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:2', 'y-dimension:1']",
#   u"['x-dimension:2', 'y-dimension:1']"],
#  [u's81t23',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:3', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's102t23',
#   0,
#   1,
#   '0.000',
#   "['hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'type:person']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old ', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:4', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's307t23',
#   0,
#   1,
#   '0.000',
#   "['hasGlasses:1', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:1', 'y-dimension:1']",
#   u"['hasGlasses:1', 'type:person']"],
#  [u's320t23',
#   0,
#   1,
#   '0.000',
#   "['hasBeard:1', 'hasGlasses:1', 'type:person', 'y-dimension:3']",
#   1,
#   1,
#   '1.000',
#   "['hasGlasses:1', 'type:person']",
#   u"['age:old', 'hairColour:light', 'hasBeard:1', 'hasGlasses:1', 'hasHair:1', 'hasShirt:0', 'hasSuit:0', 'hasTie:0', 'orientation:right', 'type:person', 'x-dimension:5', 'y-dimension:3']",
#   u"['hasGlasses:1', 'type:person']"]]

# %%
import training_instances
from sgd_lsl import LSLTrainer

def load_weights(run_dir, split):
    with open(os.path.join(run_dir, 'params.%d.json' % split), 'r') as infile:
        return json.load(infile)

def analyze(run_dir, ex_id, instances):
    example = None
    split = None
    
    for filename in glob(os.path.join(run_dir, 'predictions.*.jsons')):
        with open(filename, 'r') as infile:
            for line in infile:
                ex = json.loads(line)
                if ex['id'] == ex_id:
                    example = ex
                    split = int(filename.split('.')[1])
                    break
            
            if split is not None: break
    
    dataset = instances(filenames=glob('../TUNA/corpus/*/*/*.xml'))
    # dataset = training_instances.add_relevant_alts(dataset)
    (to_analyze,) = [d for d in dataset if d[0] == ex_id]
    id, x, y, domain, attrs, alts = to_analyze

    w = load_weights(run_dir, split)
    t = LSLTrainer(samples_x=10)
    t.predict(example['input'], w, domain, alts, verbose=2)


analyze('runs/309', 's320t23', training_instances.get_generation_instances)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-238-18804454841e> in <module>()
#      30
#      31
# ---> 32 analyze('runs/309', 's320t23', training_instances.get_generation_instances)
#
# <ipython-input-238-18804454841e> in analyze(run_dir, ex_id, instances)
#      26
#      27     w = load_weights(run_dir, split)
# ---> 28     t = LSLTrainer(samples_x=10)
#      29     t.predict(example['input'], w, domain, alts, verbose=2)
#      30
#
# NameError: global name 'LSLTrainer' is not defined
